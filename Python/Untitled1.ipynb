# %%
import pandas as pd
import numpy as np

# %%
apps = pd.read_csv("appstore_games.csv")
print(apps)
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 6      https://apps.apple.com/us/app/gravitation/id28...   286313771
# 7       https://apps.apple.com/us/app/colony/id286363959   286363959
# 8        https://apps.apple.com/us/app/carte/id286566987   286566987
# 9      https://apps.apple.com/us/app/barrels-o-fun/id...   286682679
# 10     https://apps.apple.com/us/app/quaddraxx/id2875...   287563734
# 11     https://apps.apple.com/us/app/lumen-lite/id288...   288096268
# 12     https://apps.apple.com/us/app/bubblepop/id2886...   288669794
# ...

# %%
apps.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
apps.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
apps.shape
apps.isnull()
print(apps)
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 6      https://apps.apple.com/us/app/gravitation/id28...   286313771
# 7       https://apps.apple.com/us/app/colony/id286363959   286363959
# 8        https://apps.apple.com/us/app/carte/id286566987   286566987
# 9      https://apps.apple.com/us/app/barrels-o-fun/id...   286682679
# 10     https://apps.apple.com/us/app/quaddraxx/id2875...   287563734
# 11     https://apps.apple.com/us/app/lumen-lite/id288...   288096268
# 12     https://apps.apple.com/us/app/bubblepop/id2886...   288669794
# ...

# %%
apps.isnull().sum()
# Out:
# URL                                 0
# ID                                  0
# Name                                0
# Subtitle                        11746
# Icon URL                            0
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
#1
modified_apps = apps.dropna()
modified_apps.isnull()
print(modified_apps)
# Out:
#                                                      URL          ID  \
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 19     https://apps.apple.com/us/app/cool-sudoku-jigs...   290614255
# 75     https://apps.apple.com/us/app/gun-runner/id306...   306165224
# 90     https://apps.apple.com/us/app/uniwar-multiplay...   311456818
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# 118      https://apps.apple.com/us/app/chess/id319305999   319305999
# 127    https://apps.apple.com/us/app/pixel-starships/...   321756558
# 128      https://apps.apple.com/us/app/pushy/id322110989   322110989
# 156    https://apps.apple.com/us/app/chess-play-learn...   329218549
# 168    https://apps.apple.com/us/app/tic-tac-toe-3-in...   333178201
# 180    https://apps.apple.com/us/app/catan-classic/id...   335029050
# 182    https://apps.apple.com/us/app/towermadness-zer...   335249553
# 193    https://apps.apple.com/us/app/travelers-quest/...   337209160
# ...

# %%
modified_apps.head(10)
# Out:
#                                                    URL         ID  \
# 5    https://apps.apple.com/us/app/sudoku-classic-n...  286210009
# 19   https://apps.apple.com/us/app/cool-sudoku-jigs...  290614255
# 75   https://apps.apple.com/us/app/gun-runner/id306...  306165224
# 90   https://apps.apple.com/us/app/uniwar-multiplay...  311456818
# 106  https://apps.apple.com/us/app/towermadness/id3...  316491616
# 118    https://apps.apple.com/us/app/chess/id319305999  319305999
# 127  https://apps.apple.com/us/app/pixel-starships/...  321756558
# 128    https://apps.apple.com/us/app/pushy/id322110989  322110989
# 156  https://apps.apple.com/us/app/chess-play-learn...  329218549
# 168  https://apps.apple.com/us/app/tic-tac-toe-3-in...  333178201
#
#                                Name                        Subtitle  \
# 5    Sudoku - Classic number puzzle         Original brain training
# 19      Cool Sudoku, Jigsaw, Killer  Sudoku, Jigsaw, Killer, Kakuro
# ...

# %%
modified_apps1=modified_apps[modified_apps['Average User Rating']>= 4.0]
print(modified_apps1)
# Out:
#                                                      URL          ID  \
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# 118      https://apps.apple.com/us/app/chess/id319305999   319305999
# 127    https://apps.apple.com/us/app/pixel-starships/...   321756558
# 128      https://apps.apple.com/us/app/pushy/id322110989   322110989
# 156    https://apps.apple.com/us/app/chess-play-learn...   329218549
# 180    https://apps.apple.com/us/app/catan-classic/id...   335029050
# 182    https://apps.apple.com/us/app/towermadness-zer...   335249553
# 193    https://apps.apple.com/us/app/travelers-quest/...   337209160
# 228    https://apps.apple.com/us/app/instant-chess/id...   347920086
# 261    https://apps.apple.com/us/app/espn-tournament-...   359891723
# 300    https://apps.apple.com/us/app/erics-spider-sol...   367278729
# 309    https://apps.apple.com/us/app/towermadness-hd/...   368841090
# 323    https://apps.apple.com/us/app/blood-honor-no-a...   373002953
# ...

# %%
modified_apps1['Genres']
# Out:
# 106                           Games, Strategy, Puzzle
# 118             Games, Strategy, Board, Entertainment
# 127      Games, Entertainment, Strategy, Role Playing
# 128                Games, Puzzle, Strategy, Education
# 156             Games, Strategy, Board, Entertainment
# 180             Games, Board, Strategy, Entertainment
# 182                           Games, Puzzle, Strategy
# 193                   Games, Family, Travel, Strategy
# 228                 Games, Board, Lifestyle, Strategy
# 261                   Sports, Strategy, Sports, Games
# 300              Games, Card, Entertainment, Strategy
# 309                           Games, Action, Strategy
# 323             Games, Board, Strategy, Entertainment
# 343            Games, Entertainment, Strategy, Puzzle
# 345            Games, Strategy, Entertainment, Puzzle
# 348             Games, Strategy, Board, Entertainment
# 350            Games, Puzzle, Strategy, Entertainment
# ...

# %%
modified_apps1.get(['Genres'])
# Out:
#                                              Genres
# 106                         Games, Strategy, Puzzle
# 118           Games, Strategy, Board, Entertainment
# 127    Games, Entertainment, Strategy, Role Playing
# 128              Games, Puzzle, Strategy, Education
# 156           Games, Strategy, Board, Entertainment
# 180           Games, Board, Strategy, Entertainment
# 182                         Games, Puzzle, Strategy
# 193                 Games, Family, Travel, Strategy
# 228               Games, Board, Lifestyle, Strategy
# 261                 Sports, Strategy, Sports, Games
# 300            Games, Card, Entertainment, Strategy
# 309                         Games, Action, Strategy
# 323           Games, Board, Strategy, Entertainment
# 343          Games, Entertainment, Strategy, Puzzle
# 345          Games, Strategy, Entertainment, Puzzle
# 348           Games, Strategy, Board, Entertainment
# 350          Games, Puzzle, Strategy, Entertainment
# ...

# %%
modified_apps1['Genres'].max()
# Out:
# 'Utilities, Strategy, Games, Adventure'

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()

# scatter the sepal_length against the sepal_width
ax.scatter(modified_apps1['Genres'], modified_apps1['Average User Rating'])
# set a title and labels
ax.set_title('Analysis of Apps Store')
ax.set_xlabel('Genres')
ax.set_ylabel('Average User Rating')
# Out:
# Text(0, 0.5, 'Average User Rating')

# %%
import seaborn as sns

# %%
new = modified_apps1.filter(['Genres','Average User Rating'],axis=1)

# %%
new.max()
new['Average User Rating'].max()
new
# Out:
#                                              Genres  Average User Rating
# 106                         Games, Strategy, Puzzle                  4.0
# 118           Games, Strategy, Board, Entertainment                  4.5
# 127    Games, Entertainment, Strategy, Role Playing                  4.5
# 128              Games, Puzzle, Strategy, Education                  4.0
# 156           Games, Strategy, Board, Entertainment                  4.5
# 180           Games, Board, Strategy, Entertainment                  4.0
# 182                         Games, Puzzle, Strategy                  4.0
# 193                 Games, Family, Travel, Strategy                  4.0
# 228               Games, Board, Lifestyle, Strategy                  4.0
# 261                 Sports, Strategy, Sports, Games                  4.0
# 300            Games, Card, Entertainment, Strategy                  4.5
# 309                         Games, Action, Strategy                  4.5
# ...

# %%
#3 question
modified_apps2 = modified_apps1[ modified_apps1['Average User Rating']== 5.0 ]
modified_apps2
# Out:
#                                                      URL          ID  \
# 1431   https://apps.apple.com/us/app/conceptis-sudoku...   537201666
# 1649   https://apps.apple.com/us/app/bloons-td-5/id56...   563718995
# 1672   https://apps.apple.com/us/app/conceptis-hashi/...   567583852
# 1789   https://apps.apple.com/us/app/conceptis-nurika...   581912445
# 1951   https://apps.apple.com/us/app/simply-sudoku/id...   600521463
# 1995   https://apps.apple.com/us/app/conceptis-slithe...   605918324
# 2014   https://apps.apple.com/us/app/x-war-clash-of-z...   608847384
# 2320   https://apps.apple.com/us/app/conceptis-tic-ta...   658817018
# 2437   https://apps.apple.com/us/app/kickbase-bundesl...   678241305
# 2567      https://apps.apple.com/us/app/nrtm/id695468874   695468874
# 2674   https://apps.apple.com/us/app/mazebert-td/id71...   714699723
# 2744   https://apps.apple.com/us/app/route-out-puzzle...   721913689
# 2901   https://apps.apple.com/us/app/mutility-life-co...   741336884
# ...

# %%
modified_apps2['Genres']
# Out:
# 1431               Games, Strategy, Entertainment, Puzzle
# 1649               Games, Action, Entertainment, Strategy
# 1672               Games, Entertainment, Puzzle, Strategy
# 1789               Games, Strategy, Entertainment, Puzzle
# 1951                              Games, Puzzle, Strategy
# 1995               Games, Puzzle, Strategy, Entertainment
# 2014                          Games, Strategy, Simulation
# 2320               Games, Entertainment, Strategy, Puzzle
# 2437                      Games, Sports, Strategy, Sports
# 2567                                Games, Strategy, Card
# 2674                          Games, Simulation, Strategy
# 2744                   Games, Strategy, Puzzle, Education
# 2901                 Entertainment, Card, Strategy, Games
# 3131     Games, Strategy, Role Playing, Social Networking
# 3225                          Games, Simulation, Strategy
# 3242                Games, Board, Entertainment, Strategy
# ...

# %%
]
# Out:
# 106      False
# 118      False
# 127      False
# 128      False
# 156      False
# 180      False
# 182      False
# 193      False
# 228      False
# 261      False
# 300      False
# 309      False
# 323      False
# 343      False
# 345      False
# 348      False
# 350      False
# 358      False
# 379      False
# 386      False
# 392      False
# 399      False
# 401      False
# 415      False
# 431      False
# 446      False
# 473      False
# 500      False
# 506      False
# 507      False
#          ...
# 16524    False
# 16525    False
# 16529    False
# 16536    False
# 16543    False
# 16548    False
# 16553    False
# 16569    False
# 16580    False
# 16596    False
# 16601    False
# 16606    False
# 16629    False
# 16647    False
# 16654    False
# 16694    False
# 16708    False
# 16716    False
# 16718    False
# 16735    False
# 16740    False
# 16748    False
# 16758    False
# 16763    False
# 16772    False
# 16789    False
# 16791    False
# ...

# %%
y1 = modified_apps1['Genres'] == 'Utilities'
sns.catplot(x="Average User Rating", y=y1, data=modified_apps1);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-132-73f88b3c9bb1> in <module>
#       1 y1 = modified_apps1['Genres'] == 'Utilities'
# ----> 2 sns.catplot(x="Average User Rating", y=y1, data=modified_apps1);
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# ...

# %%
modified_apps2=modified_apps[modified_apps['Average User Rating']>= 4.0 and modified_apps.Genres == "Utilities"]
modified_apps2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-9a8d575137b5> in <module>
# ----> 1 modified_apps2=modified_apps[modified_apps['Average User Rating']>= 4.0 and modified_apps.Genres == "Utilities"]
#       2 modified_apps2
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
sns.relplot(x="User Rating Count", y="Price",
            dashes=False, markers=True, kind="line", data=modified_apps1)

# %%
#4
x= modified_apps['User Rating Count']
y=modified_apps['Price']
plt.scatter(x,y)
